# %%
import torch

# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"Using device: {device}")
# Expected output on your machine: "Using device: cuda"
# Out:
# Using device: cuda

# %% [markdown]
# ## Extract text from pdf file using granite docling
# Granite Docling is a open source model

# %%
import torch
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import PipelineOptions, AcceleratorOptions, AcceleratorDevice, VlmPipelineOptions
from docling.pipeline.vlm_pipeline import VlmPipeline
from docling.datamodel import vlm_model_specs

# on nvidia RTX 3050 (4GB RAM)
accelerator_options = AcceleratorOptions(
    num_threads=4, 
    device=AcceleratorDevice.CUDA  # Forces NVIDIA GPU
)

# now we set up the granite docling 
pipeline_options = VlmPipelineOptions(
    accelerator_options=accelerator_options,
    vlm_options=vlm_model_specs.GRANITE_DOCLING # <--- Specifies the IBM Granite Model
)

# Initialize the Converter
converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(
            pipeline_cls=VlmPipeline, 
            pipeline_options=pipeline_options
        )
    }
)

print(f"Converter Ready on Device: {torch.cuda.get_device_name(0)}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 17
#       9 accelerator_options = AcceleratorOptions(
#      10     num_threads=4,
#      11     device=AcceleratorDevice.CUDA  # Forces NVIDIA GPU
#      12 )
#      14 # now we set up the granite docling
#      15 pipeline_options = VlmPipelineOptions(
#      16     accelerator_options=accelerator_options,
# ---> 17     vlm_options=vlm_model_specs.GRANITE_DOCLING # <--- Specifies the IBM Granite Model
#      18 )
#      20 # Initialize the Converter
#      21 converter = DocumentConverter(
#      22     format_options={
#      23         InputFormat.PDF: PdfFormatOption(
#    (...)     27     }
#      28 )
#
# AttributeError: module 'docling.datamodel.vlm_model_specs' has no attribute 'GRANITE_DOCLING'
